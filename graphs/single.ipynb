# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    model='openai/gpt-oss-120b',
    temperature=0
)

# %%
response = llm.invoke(
    "You are a teacher. Give one motivational sentence for a Python student."
)

# %%
response.content
# Out:
# '"Keep coding, because every line you write brings you one step closer to turning ideas into powerful, real‑world Python solutions!"'
